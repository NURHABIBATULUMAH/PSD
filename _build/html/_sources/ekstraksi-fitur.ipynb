# %%
pip install tsfel pandas
# Out:
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    -------------- ------------------------- 1.6/4.2 MB 9.3 MB/s eta 0:00:01
#    --------------------------- ------------ 2.9/4.2 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 7.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.2 MB 10.7 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.2 MB 10.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 10.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 7.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/36.7 MB ? eta -:--:--
# ...
